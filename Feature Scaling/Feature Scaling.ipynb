# %% [markdown]
# ## Feature Scaling

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Student_performance_data _.csv")

# %%
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %% [markdown]
# Two types of Feature Sacling are:
# 1. Normalization
# 2. Standardization
#
# **Normalization**
#
# - It is also called **MIN-MAX** Feature Sacling.
# - In this technique we use a formula to rescale the value between 0-1.
# - i.e.. X'=(X-X(min))/X(max)-X(min)
#
# **Standardization**
#
# - It is also called **Z-score**
# - Standardization is another scaling technique where the values are centered around the mean with a unit standard deviation.
# - formula for this is : x' = (x-mean)/S.D

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.describe().round(2)
#we have rounded each data upto its 2 place decimal value
# Out:
#        StudentID      Age   Gender  Ethnicity  ParentalEducation  \
# count    2392.00  2392.00  2392.00    2392.00            2392.00
# mean     2196.50    16.47     0.51       0.88               1.75
# std       690.66     1.12     0.50       1.03               1.00
# min      1001.00    15.00     0.00       0.00               0.00
# 25%      1598.75    15.00     0.00       0.00               1.00
# 50%      2196.50    16.00     1.00       0.00               2.00
# 75%      2794.25    17.00     1.00       2.00               2.00
# max      3392.00    18.00     1.00       3.00               4.00
#
#        StudyTimeWeekly  Absences  Tutoring  ParentalSupport  Extracurricular  \
# count          2392.00   2392.00   2392.00          2392.00          2392.00
# mean              9.77     14.54      0.30             2.12             0.38
# std               5.65      8.47      0.46             1.12             0.49
# ...

# %% [markdown]
# ### NORMALIZATION

# %%
new_df=pd.DataFrame(df,columns=['Age','Absences'])

# %%
new_df.head()
# Out:
#    Age  Absences
# 0   17         7
# 1   18         0
# 2   15        26
# 3   17        14
# 4   17        17

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       2392 non-null   int64
#  1   Absences  2392 non-null   int64
# dtypes: int64(2)
# memory usage: 37.5 KB

# %%
new_df.isnull().sum()
# Out:
# Age         0
# Absences    0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# MinMaxScaler is used for normalization

# %%
scaler=MinMaxScaler() 
normalized_df = scaler.fit_transform(new_df)

# %%
print(normalized_df)
# Out:
# [[0.66666667 0.24137931]
#  [1.         0.        ]
#  [0.         0.89655172]
#  ...
#  [0.33333333 0.68965517]
#  [0.33333333 0.5862069 ]
#  [0.33333333 0.44827586]]

# %% [markdown]
# it uses the formula of min-max(ie.. X=(X-Xmin)/(Xmax-Xmin)

# %% [markdown]
# ### Standardization or Z-Score

# %%
from sklearn.preprocessing import StandardScaler

# %%
s_scaler=StandardScaler()

# %%
standard=s_scaler.fit_transform(new_df)
print(standard)
# Out:
# [[ 0.47291901 -0.89082237]
#  [ 1.36294441 -1.71769358]
#  [-1.30713178  1.35354235]
#  ...
#  [-0.41710638  0.64479559]
#  [-0.41710638  0.29042222]
#  [-0.41710638 -0.18207562]]

# %% [markdown]
# if uses the form of standared scaler(i.e..  X=(X-Mean)/S.D)
